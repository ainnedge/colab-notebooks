# %%
# Detect Colab if present
try:
    from google.colab import drive
    COLAB = True
    print("Note: using Google CoLab")
    # %tensorflow_version 2.x
except:
    print("Note: not using Google CoLab")
    COLAB = False

# Nicely formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return f"{h}:{m:>02}:{s:>05.2f}"
# Out:
# Note: using Google CoLab

# %%
hms_string(120)
# Out:
# '0:02:00.00'

# %%
from __future__ import print_function
import tensorflow.keras
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation, AveragePooling2D, Input, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
import numpy as np
import os

# %%
#load data
(x_train,y_train), (x_test,y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1), (10000, 32, 32, 3), (10000, 1))

# %%
#watch dataset
# %matplotlib inline
import matplotlib.pyplot as plt
from six.moves import cPickle

ROWS = 10
x = x_train.astype('uint8')
fig, axesl = plt.subplots(ROWS,ROWS, figsize=(10,10))
for i in range(ROWS):
  for j in range(ROWS):
    k = np.random.choice(range(len(x)))
    axesl[i][j].set_axis_off()
    axesl[i][j].imshow(x[k:k+1][0])

# %%
# Training parameters
BATCH_SIZE = 32  # orig paper trained all networks with batch_size=128
EPOCHS = 200 # 200
USE_AUGMENTATION = False
NUM_CLASSES = np.unique(y_train).shape[0] # 10
COLORS = x_train.shape[3]

# Subtracting pixel mean improves accuracy
SUBTRACT_PIXEL_MEAN = True

# Model version
# Orig paper: version = 1 (ResNet v1), 
# Improved ResNet: version = 2 
# (ResNet v2)
VERSION = 1

# Computed depth from supplied model parameter n
if VERSION == 1:
    DEPTH = COLORS * 6 + 2
elif version == 2:
    DEPTH = COLORS * 9 + 2

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=False,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature 
    map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of 
    filters is
    doubled. Within each stage, the layers have the same number 
    filters and the same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            # first layer but not first stack
            if stack > 0 and res_block == 0:  
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            # first layer but not first stack
            if stack > 0 and res_block == 0:  
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = tensorflow.keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if SUBTRACT_PIXEL_MEAN:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = tensorflow.keras.utils.to_categorical(y_train, NUM_CLASSES)
y_test = tensorflow.keras.utils.to_categorical(y_test, NUM_CLASSES)

print("***", VERSION)
# Create the neural network
model = resnet_v1(input_shape=input_shape, depth=DEPTH)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)
# *** 1
# Learning rate:  0.001
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 16)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   2320        activation[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   2320        activation_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 16)   0           activation[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 16)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 16)   2320        activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 16)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 16)   2320        activation_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 16)   0           activation_2[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 16)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 16)   2320        activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 16)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 16)   2320        activation_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 16)   0           activation_4[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 16)   0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 32)   4640        activation_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 32)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 32)   544         activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 32)   9248        activation_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 32)   0           conv2d_9[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 32)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 32)   9248        activation_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 32)   0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 32)   9248        activation_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 32)   0           activation_8[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 32)   0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 32)   9248        activation_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 32)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 32)   9248        activation_11[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 32)   0           activation_10[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 32)   0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 64)     18496       activation_12[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 64)     0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 64)     2112        activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 64)     36928       activation_13[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 64)     0           conv2d_16[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 64)     0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 64)     36928       activation_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 8, 64)     0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 64)     36928       activation_15[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 64)     0           activation_14[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 64)     0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 64)     36928       activation_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 64)     0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 64)     36928       activation_17[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 8, 64)     0           activation_16[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 64)     0           add_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 64)     0           activation_18[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 64)           0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           650         flatten[0][0]
# ==================================================================================================
# Total params: 271,690
# Trainable params: 271,690
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
import time

start_time = time.time()

# Prepare callbacks for model saving and for learning rate adjustment.
lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [lr_reducer, lr_scheduler]

# Run training, with or without data augmentation.
if not USE_AUGMENTATION:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=BATCH_SIZE,
              epochs=EPOCHS,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation 
        # (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train, 
                        batch_size=BATCH_SIZE),
                        validation_data=(x_test, y_test),
                        epochs=EPOCHS,
                        verbose=0,
                        workers=1,
                        callbacks=callbacks,
                        use_multiprocessing=False
                      )
    
elapsed_time = time.time() - start_time
print("Elapsed time: {}".format(hms_string(elapsed_time)))

#save the model as SavedModel
model.save("saved_model/resnet18")
# Out:
# Not using data augmentation.
# Epoch 1/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 51s 12ms/step - loss: 1.8375 - accuracy: 0.3622 - val_loss: 1.5900 - val_accuracy: 0.4636
# Epoch 2/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.3915 - accuracy: 0.5379 - val_loss: 1.2157 - val_accuracy: 0.6087
# Epoch 3/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.1445 - accuracy: 0.6363 - val_loss: 1.1242 - val_accuracy: 0.6480
# Epoch 4/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9952 - accuracy: 0.6960 - val_loss: 1.0829 - val_accuracy: 0.6619
# Epoch 5/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8956 - accuracy: 0.7340 - val_loss: 0.9461 - val_accuracy: 0.7151
# Epoch 6/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8236 - accuracy: 0.7628 - val_loss: 0.8876 - val_accuracy: 0.7421
# Epoch 7/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7728 - accuracy: 0.7835 - val_loss: 0.9649 - val_accuracy: 0.7235
# Epoch 8/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.7357 - accuracy: 0.7983 - val_loss: 0.8463 - val_accuracy: 0.7680
# Epoch 9/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.6961 - accuracy: 0.8143 - val_loss: 0.8987 - val_accuracy: 0.7570
# Epoch 10/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.6730 - accuracy: 0.8246 - val_loss: 0.8607 - val_accuracy: 0.7723
# Epoch 11/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.6423 - accuracy: 0.8409 - val_loss: 0.9128 - val_accuracy: 0.7602
# Epoch 12/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.6237 - accuracy: 0.8480 - val_loss: 0.9103 - val_accuracy: 0.7627
# Epoch 13/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.6017 - accuracy: 0.8557 - val_loss: 0.8847 - val_accuracy: 0.7733
# Epoch 14/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.5869 - accuracy: 0.8664 - val_loss: 0.9099 - val_accuracy: 0.7760
# Epoch 15/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.5742 - accuracy: 0.8721 - val_loss: 0.9290 - val_accuracy: 0.7716
# Epoch 16/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.5587 - accuracy: 0.8807 - val_loss: 0.9047 - val_accuracy: 0.7797
# Epoch 17/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.5519 - accuracy: 0.8837 - val_loss: 0.9356 - val_accuracy: 0.7736
# Epoch 18/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.5385 - accuracy: 0.8887 - val_loss: 0.9644 - val_accuracy: 0.7837
# Epoch 19/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.5353 - accuracy: 0.8932 - val_loss: 0.9507 - val_accuracy: 0.7858
# Epoch 20/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.5239 - accuracy: 0.8982 - val_loss: 0.9524 - val_accuracy: 0.7837
# Epoch 21/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.5215 - accuracy: 0.9016 - val_loss: 1.0043 - val_accuracy: 0.7768
# Epoch 22/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.5154 - accuracy: 0.9038 - val_loss: 0.9922 - val_accuracy: 0.7718
# Epoch 23/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.5119 - accuracy: 0.9075 - val_loss: 1.0724 - val_accuracy: 0.7690
# Epoch 24/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.5051 - accuracy: 0.9093 - val_loss: 1.0239 - val_accuracy: 0.7761
# Epoch 25/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.5071 - accuracy: 0.9095 - val_loss: 1.0309 - val_accuracy: 0.7830
# Epoch 26/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4943 - accuracy: 0.9162 - val_loss: 1.0692 - val_accuracy: 0.7767
# Epoch 27/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4965 - accuracy: 0.9167 - val_loss: 1.0650 - val_accuracy: 0.7682
# Epoch 28/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4902 - accuracy: 0.9184 - val_loss: 1.0754 - val_accuracy: 0.7814
# Epoch 29/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.4901 - accuracy: 0.9209 - val_loss: 1.0438 - val_accuracy: 0.7830
# Epoch 30/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.4917 - accuracy: 0.9191 - val_loss: 1.0589 - val_accuracy: 0.7827
# Epoch 31/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.4871 - accuracy: 0.9218 - val_loss: 1.0620 - val_accuracy: 0.7785
# Epoch 32/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.4846 - accuracy: 0.9232 - val_loss: 1.1032 - val_accuracy: 0.7730
# Epoch 33/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.4829 - accuracy: 0.9241 - val_loss: 1.1837 - val_accuracy: 0.7787
# Epoch 34/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4798 - accuracy: 0.9256 - val_loss: 1.1093 - val_accuracy: 0.7726
# Epoch 35/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4770 - accuracy: 0.9275 - val_loss: 1.1392 - val_accuracy: 0.7826
# Epoch 36/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4740 - accuracy: 0.9285 - val_loss: 1.2289 - val_accuracy: 0.7566
# Epoch 37/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4745 - accuracy: 0.9291 - val_loss: 1.1509 - val_accuracy: 0.7779
# Epoch 38/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4767 - accuracy: 0.9298 - val_loss: 1.1310 - val_accuracy: 0.7727
# Epoch 39/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4741 - accuracy: 0.9311 - val_loss: 1.1391 - val_accuracy: 0.7814
# Epoch 40/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4679 - accuracy: 0.9336 - val_loss: 1.1240 - val_accuracy: 0.7835
# Epoch 41/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4731 - accuracy: 0.9307 - val_loss: 1.1046 - val_accuracy: 0.7892
# Epoch 42/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4741 - accuracy: 0.9315 - val_loss: 1.2424 - val_accuracy: 0.7666
# Epoch 43/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4693 - accuracy: 0.9330 - val_loss: 1.1435 - val_accuracy: 0.7843
# Epoch 44/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4679 - accuracy: 0.9337 - val_loss: 1.1887 - val_accuracy: 0.7752
# Epoch 45/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4713 - accuracy: 0.9331 - val_loss: 1.1634 - val_accuracy: 0.7769
# Epoch 46/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4632 - accuracy: 0.9353 - val_loss: 1.1856 - val_accuracy: 0.7816
# Epoch 47/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.4617 - accuracy: 0.9358 - val_loss: 1.1533 - val_accuracy: 0.7853
# Epoch 48/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.4591 - accuracy: 0.9380 - val_loss: 1.1876 - val_accuracy: 0.7808
# Epoch 49/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.4587 - accuracy: 0.9384 - val_loss: 1.1459 - val_accuracy: 0.7807
# Epoch 50/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.4624 - accuracy: 0.9359 - val_loss: 1.2346 - val_accuracy: 0.7601
# Epoch 51/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4603 - accuracy: 0.9377 - val_loss: 1.1517 - val_accuracy: 0.7838
# Epoch 52/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4531 - accuracy: 0.9402 - val_loss: 1.1734 - val_accuracy: 0.7820
# Epoch 53/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4565 - accuracy: 0.9389 - val_loss: 1.2138 - val_accuracy: 0.7705
# Epoch 54/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4574 - accuracy: 0.9390 - val_loss: 1.1548 - val_accuracy: 0.7785
# Epoch 55/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4491 - accuracy: 0.9417 - val_loss: 1.2355 - val_accuracy: 0.7685
# Epoch 56/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4484 - accuracy: 0.9414 - val_loss: 1.2095 - val_accuracy: 0.7746
# Epoch 57/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4500 - accuracy: 0.9414 - val_loss: 1.2226 - val_accuracy: 0.7736
# Epoch 58/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4489 - accuracy: 0.9413 - val_loss: 1.2608 - val_accuracy: 0.7713
# Epoch 59/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4512 - accuracy: 0.9413 - val_loss: 1.2027 - val_accuracy: 0.7674
# Epoch 60/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4445 - accuracy: 0.9435 - val_loss: 1.1878 - val_accuracy: 0.7760
# Epoch 61/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4471 - accuracy: 0.9427 - val_loss: 1.2729 - val_accuracy: 0.7702
# Epoch 62/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4474 - accuracy: 0.9434 - val_loss: 1.2041 - val_accuracy: 0.7776
# Epoch 63/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.4443 - accuracy: 0.9438 - val_loss: 1.1924 - val_accuracy: 0.7810
# Epoch 64/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.4513 - accuracy: 0.9405 - val_loss: 1.1012 - val_accuracy: 0.7885
# Epoch 65/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.4440 - accuracy: 0.9439 - val_loss: 1.1733 - val_accuracy: 0.7791
# Epoch 66/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.4369 - accuracy: 0.9462 - val_loss: 1.1541 - val_accuracy: 0.7848
# Epoch 67/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.4435 - accuracy: 0.9438 - val_loss: 1.3155 - val_accuracy: 0.7649
# Epoch 68/200
# Learning rate:  0.001
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.
200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.1136 - accuracy: 1.0000 - val_loss: 1.7770 - val_accuracy: 0.8208
# Epoch 129/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.1117 - accuracy: 1.0000 - val_loss: 1.8175 - val_accuracy: 0.8219
# Epoch 130/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.1098 - accuracy: 1.0000 - val_loss: 1.8321 - val_accuracy: 0.8209
# Epoch 131/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.1082 - accuracy: 1.0000 - val_loss: 1.8472 - val_accuracy: 0.8200
# Epoch 132/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.1067 - accuracy: 1.0000 - val_loss: 1.8694 - val_accuracy: 0.8201
# Epoch 133/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.1053 - accuracy: 1.0000 - val_loss: 1.8877 - val_accuracy: 0.8207
# Epoch 134/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.1041 - accuracy: 1.0000 - val_loss: 1.9073 - val_accuracy: 0.8194
# Epoch 135/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.1028 - accuracy: 1.0000 - val_loss: 1.9343 - val_accuracy: 0.8188
# Epoch 136/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.1017 - accuracy: 1.0000 - val_loss: 1.9424 - val_accuracy: 0.8192
# Epoch 137/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.1006 - accuracy: 1.0000 - val_loss: 1.9760 - val_accuracy: 0.8173
# Epoch 138/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0996 - accuracy: 1.0000 - val_loss: 1.9750 - val_accuracy: 0.8182
# Epoch 139/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0987 - accuracy: 1.0000 - val_loss: 1.9958 - val_accuracy: 0.8175
# Epoch 140/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0978 - accuracy: 1.0000 - val_loss: 2.0317 - val_accuracy: 0.8185
# Epoch 141/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0969 - accuracy: 1.0000 - val_loss: 2.0265 - val_accuracy: 0.8184
# Epoch 142/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0960 - accuracy: 1.0000 - val_loss: 2.0606 - val_accuracy: 0.8168
# Epoch 143/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0952 - accuracy: 1.0000 - val_loss: 2.0748 - val_accuracy: 0.8159
# Epoch 144/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0944 - accuracy: 1.0000 - val_loss: 2.0974 - val_accuracy: 0.8153
# Epoch 145/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0936 - accuracy: 1.0000 - val_loss: 2.0985 - val_accuracy: 0.8150
# Epoch 146/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0928 - accuracy: 1.0000 - val_loss: 2.1143 - val_accuracy: 0.8159
# Epoch 147/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0921 - accuracy: 1.0000 - val_loss: 2.1331 - val_accuracy: 0.8168
# Epoch 148/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0914 - accuracy: 1.0000 - val_loss: 2.1720 - val_accuracy: 0.8160
# Epoch 149/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0907 - accuracy: 1.0000 - val_loss: 2.1776 - val_accuracy: 0.8140
# Epoch 150/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0900 - accuracy: 1.0000 - val_loss: 2.1879 - val_accuracy: 0.8148
# Epoch 151/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0894 - accuracy: 1.0000 - val_loss: 2.1921 - val_accuracy: 0.8159
# Epoch 152/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0888 - accuracy: 0.9999 - val_loss: 2.2024 - val_accuracy: 0.8152
# Epoch 153/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0882 - accuracy: 1.0000 - val_loss: 2.2228 - val_accuracy: 0.8154
# Epoch 154/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0877 - accuracy: 1.0000 - val_loss: 2.2276 - val_accuracy: 0.8156
# Epoch 155/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0872 - accuracy: 1.0000 - val_loss: 2.2443 - val_accuracy: 0.8151
# Epoch 156/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0866 - accuracy: 1.0000 - val_loss: 2.2580 - val_accuracy: 0.8141
# Epoch 157/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0861 - accuracy: 1.0000 - val_loss: 2.3102 - val_accuracy: 0.8124
# Epoch 158/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0859 - accuracy: 0.9999 - val_loss: 2.2564 - val_accuracy: 0.8154
# Epoch 159/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0853 - accuracy: 1.0000 - val_loss: 2.2830 - val_accuracy: 0.8150
# Epoch 160/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0849 - accuracy: 1.0000 - val_loss: 2.2722 - val_accuracy: 0.8140
# Epoch 161/200
# Learning rate:  1e-05
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0844 - accuracy: 1.0000 - val_loss: 2.3052 - val_accuracy: 0.8139
# Epoch 162/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0839 - accuracy: 1.0000 - val_loss: 2.3109 - val_accuracy: 0.8147
# Epoch 163/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0838 - accuracy: 1.0000 - val_loss: 2.3148 - val_accuracy: 0.8145
# Epoch 164/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0837 - accuracy: 1.0000 - val_loss: 2.3218 - val_accuracy: 0.8146
# Epoch 165/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0836 - accuracy: 1.0000 - val_loss: 2.3285 - val_accuracy: 0.8147
# Epoch 166/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0835 - accuracy: 1.0000 - val_loss: 2.3290 - val_accuracy: 0.8145
# Epoch 167/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0834 - accuracy: 1.0000 - val_loss: 2.3326 - val_accuracy: 0.8148
# Epoch 168/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0833 - accuracy: 1.0000 - val_loss: 2.3375 - val_accuracy: 0.8141
# Epoch 169/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0832 - accuracy: 1.0000 - val_loss: 2.3396 - val_accuracy: 0.8147
# Epoch 170/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0831 - accuracy: 1.0000 - val_loss: 2.3430 - val_accuracy: 0.8139
# Epoch 171/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0830 - accuracy: 1.0000 - val_loss: 2.3502 - val_accuracy: 0.8147
# Epoch 172/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0829 - accuracy: 1.0000 - val_loss: 2.3501 - val_accuracy: 0.8147
# Epoch 173/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0828 - accuracy: 1.0000 - val_loss: 2.3496 - val_accuracy: 0.8145
# Epoch 174/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0828 - accuracy: 1.0000 - val_loss: 2.3545 - val_accuracy: 0.8143
# Epoch 175/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0827 - accuracy: 1.0000 - val_loss: 2.3596 - val_accuracy: 0.8146
# Epoch 176/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0826 - accuracy: 1.0000 - val_loss: 2.3582 - val_accuracy: 0.8141
# Epoch 177/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0825 - accuracy: 1.0000 - val_loss: 2.3636 - val_accuracy: 0.8143
# Epoch 178/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0824 - accuracy: 1.0000 - val_loss: 2.3641 - val_accuracy: 0.8143
# Epoch 179/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0823 - accuracy: 1.0000 - val_loss: 2.3666 - val_accuracy: 0.8141
# Epoch 180/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0822 - accuracy: 1.0000 - val_loss: 2.3656 - val_accuracy: 0.8141
# Epoch 181/200
# Learning rate:  1e-06
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0821 - accuracy: 1.0000 - val_loss: 2.3684 - val_accuracy: 0.8141
# Epoch 182/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0821 - accuracy: 1.0000 - val_loss: 2.3718 - val_accuracy: 0.8142
# Epoch 183/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0820 - accuracy: 1.0000 - val_loss: 2.3737 - val_accuracy: 0.8142
# Epoch 184/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0820 - accuracy: 1.0000 - val_loss: 2.3742 - val_accuracy: 0.8137
# Epoch 185/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0819 - accuracy: 1.0000 - val_loss: 2.3758 - val_accuracy: 0.8144
# Epoch 186/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0819 - accuracy: 1.0000 - val_loss: 2.3763 - val_accuracy: 0.8147
# Epoch 187/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0818 - accuracy: 1.0000 - val_loss: 2.3793 - val_accuracy: 0.8143
# Epoch 188/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0818 - accuracy: 1.0000 - val_loss: 2.3785 - val_accuracy: 0.8138
# Epoch 189/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0818 - accuracy: 1.0000 - val_loss: 2.3794 - val_accuracy: 0.8140
# Epoch 190/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0817 - accuracy: 1.0000 - val_loss: 2.3804 - val_accuracy: 0.8144
# Epoch 191/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0817 - accuracy: 1.0000 - val_loss: 2.3813 - val_accuracy: 0.8147
# Epoch 192/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0816 - accuracy: 1.0000 - val_loss: 2.3827 - val_accuracy: 0.8147
# Epoch 193/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0816 - accuracy: 1.0000 - val_loss: 2.3833 - val_accuracy: 0.8143
# Epoch 194/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0816 - accuracy: 1.0000 - val_loss: 2.3850 - val_accuracy: 0.8137
# Epoch 195/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0815 - accuracy: 1.0000 - val_loss: 2.3870 - val_accuracy: 0.8147
# Epoch 196/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0815 - accuracy: 1.0000 - val_loss: 2.3867 - val_accuracy: 0.8145
# Epoch 197/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0814 - accuracy: 1.0000 - val_loss: 2.3862 - val_accuracy: 0.8139
# Epoch 198/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0814 - accuracy: 1.0000 - val_loss: 2.3888 - val_accuracy: 0.8139
# Epoch 199/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0813 - accuracy: 1.0000 - val_loss: 2.3913 - val_accuracy: 0.8148
# Epoch 200/200
# Learning rate:  5e-07
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0813 - accuracy: 1.0000 - val_loss: 2.3909 - val_accuracy: 0.8144
# Elapsed time: 0:59:24.01
# INFO:tensorflow:Assets written to: saved_model/resnet18/assets
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
